# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid='+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat=city_weather["coord"]["lat"]
        lng=city_weather["coord"]["lon"]
        maxtemp=city_weather["main"]["temp_max"]
        humidity=city_weather["main"]["humidity"]
        cloudiness=city_weather["clouds"]["all"]
        wind=city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        description=city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": maxtemp,
                          "Humidity": humidity,
                          "Cloudiness": cloudiness,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": description
                         })
            
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | miyako
# Processing Record 4 of Set 1 | santa cruz
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | solnechnyy
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | vardo
# Processing Record 12 of Set 1 | khokhlovo
# Processing Record 13 of Set 1 | ouango
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | kavieng
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | abu kamal
# Processing Record 18 of Set 1 | ocampo
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | jacareacanga
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | biscarrosse
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | kodarma
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | san vicente
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | paita
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | port blair
# Processing Record 38 of Set 1 | guicheng
# City not found. Skipping...
# Processing Record 39 of Set 1 | saravan
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | askarovo
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | okhotsk
# Processing Record 49 of Set 1 | constitucion
# Processing Record 50 of Set 1 | margate
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | broken hill
# Processing Record 4 of Set 2 | sao jose da coroa grande
# Processing Record 5 of Set 2 | hasaki
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | bukachacha
# Processing Record 9 of Set 2 | namie
# Processing Record 10 of Set 2 | juneau
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | rio gallegos
# Processing Record 15 of Set 2 | yumen
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | oxford
# Processing Record 18 of Set 2 | lethem
# Processing Record 19 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | fare
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | pafos
# Processing Record 26 of Set 2 | valladolid
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | sisimiut
# Processing Record 29 of Set 2 | nome
# Processing Record 30 of Set 2 | ust-kuyga
# Processing Record 31 of Set 2 | opportunity
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | lasa
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | mandalgovi
# Processing Record 37 of Set 2 | tabou
# Processing Record 38 of Set 2 | ambulu
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 2 | kutum
# Processing Record 43 of Set 2 | kloulklubed
# Processing Record 44 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 45 of Set 2 | egvekinot
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | ukiah
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 3 | yomou
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | salalah
# Processing Record 5 of Set 3 | severnyy-kospashskiy
# Processing Record 6 of Set 3 | adrar
# Processing Record 7 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 3 | vao
# Processing Record 9 of Set 3 | loukhi
# Processing Record 10 of Set 3 | grand gaube
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | ust-maya
# Processing Record 14 of Set 3 | mataura
# Processing Record 15 of Set 3 | contamana
# Processing Record 16 of Set 3 | agua buena
# Processing Record 17 of Set 3 | sorland
# Processing Record 18 of Set 3 | makubetsu
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | totma
# Processing Record 25 of Set 3 | yangmei
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | maldonado
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | bunia
# Processing Record 30 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | payo
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | el rosario
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | the valley
# Processing Record 42 of Set 3 | xian
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | khani
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | biak
# Processing Record 47 of Set 3 | ushtobe
# Processing Record 48 of Set 3 | kieta
# Processing Record 49 of Set 3 | hamilton
# Processing Record 50 of Set 3 | den helder
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | eureka
# Processing Record 4 of Set 4 | ossora
# Processing Record 5 of Set 4 | aleksandrovskoye
# Processing Record 6 of Set 4 | kalmunai
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | belle fourche
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | coahuayana
# Processing Record 11 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 4 | luena
# Processing Record 13 of Set 4 | tiznit
# Processing Record 14 of Set 4 | taungdwingyi
# Processing Record 15 of Set 4 | preetz
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | saint-paul
# Processing Record 18 of Set 4 | hami
# Processing Record 19 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | nishihara
# Processing Record 22 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | alice springs
# Processing Record 26 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 4 | dalbandin
# Processing Record 28 of Set 4 | bac lieu
# Processing Record 29 of Set 4 | robertson
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | santa isabel do rio negro
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | nepa nagar
# Processing Record 34 of Set 4 | chengzihe
# Processing Record 35 of Set 4 | goderich
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | bluff
# Processing Record 38 of Set 4 | aswan
# Processing Record 39 of Set 4 | edd
# Processing Record 40 of Set 4 | mtwara
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | tanete
# Processing Record 44 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 4 | belle glade
# Processing Record 46 of Set 4 | kokkola
# Processing Record 47 of Set 4 | bonito
# Processing Record 48 of Set 4 | tieli
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | thilogne
# City not found. Skipping...
# Processing Record 1 of Set 5 | nikel
# Processing Record 2 of Set 5 | kysyl-syr
# Processing Record 3 of Set 5 | agoura hills
# Processing Record 4 of Set 5 | jamestown
# Processing Record 5 of Set 5 | olavarria
# Processing Record 6 of Set 5 | richards bay
# Processing Record 7 of Set 5 | juliaca
# Processing Record 8 of Set 5 | cuxhaven
# Processing Record 9 of Set 5 | bud
# Processing Record 10 of Set 5 | inhambane
# Processing Record 11 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 5 | charlestown
# Processing Record 13 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 5 | brookhaven
# Processing Record 15 of Set 5 | verkhoyansk
# Processing Record 16 of Set 5 | palu
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | grindavik
# Processing Record 19 of Set 5 | regeneracao
# Processing Record 20 of Set 5 | porto santo
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | pizarro
# Processing Record 23 of Set 5 | marawi
# Processing Record 24 of Set 5 | matara
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | pahrump
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | kamina
# Processing Record 29 of Set 5 | udachnyy
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | vaitape
# Processing Record 33 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 5 | luoyang
# Processing Record 35 of Set 5 | pisco
# Processing Record 36 of Set 5 | baena
# Processing Record 37 of Set 5 | bafoulabe
# Processing Record 38 of Set 5 | shelburne
# Processing Record 39 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 5 | djambala
# Processing Record 41 of Set 5 | yuyao
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | gladstone
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | mananara
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | yichang
# Processing Record 48 of Set 5 | vestmannaeyjar
# Processing Record 49 of Set 5 | oussouye
# Processing Record 50 of Set 5 | paragominas
# Processing Record 1 of Set 6 | houston
# Processing Record 2 of Set 6 | vaasa
# Processing Record 3 of Set 6 | san quintin
# Processing Record 4 of Set 6 | maningrida
# Processing Record 5 of Set 6 | guerrero negro
# Processing Record 6 of Set 6 | tilichiki
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | walvis bay
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | samana
# Processing Record 11 of Set 6 | topeka
# Processing Record 12 of Set 6 | ryotsu
# Processing Record 13 of Set 6 | axim
# Processing Record 14 of Set 6 | olot
# Processing Record 15 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 6 | ouadda
# Processing Record 17 of Set 6 | abashiri
# Processing Record 18 of Set 6 | puri
# Processing Record 19 of Set 6 | dauphin
# Processing Record 20 of Set 6 | kamenka
# Processing Record 21 of Set 6 | porto nacional
# Processing Record 22 of Set 6 | naze
# Processing Record 23 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 6 | arraial do cabo
# Processing Record 25 of Set 6 | rongcheng
# Processing Record 26 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 6 | barrow
# Processing Record 28 of Set 6 | yeppoon
# Processing Record 29 of Set 6 | robertsport
# Processing Record 30 of Set 6 | micheweni
# Processing Record 31 of Set 6 | muros
# Processing Record 32 of Set 6 | paracuru
# Processing Record 33 of Set 6 | plouzane
# Processing Record 34 of Set 6 | mehran
# Processing Record 35 of Set 6 | san luis
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | bilma
# Processing Record 39 of Set 6 | taltal
# Processing Record 40 of Set 6 | pritzwalk
# Processing Record 41 of Set 6 | birobidzhan
# Processing Record 42 of Set 6 | chaihe
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | dhone
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | cheremshan
# Processing Record 47 of Set 6 | lakes entrance
# Processing Record 48 of Set 6 | nacogdoches
# Processing Record 49 of Set 6 | tiksi
# Processing Record 50 of Set 6 | kathmandu
# Processing Record 1 of Set 7 | kijang
# Processing Record 2 of Set 7 | akdepe
# Processing Record 3 of Set 7 | fukue
# Processing Record 4 of Set 7 | jutai
# Processing Record 5 of Set 7 | kirakira
# Processing Record 6 of Set 7 | nova esperanca
# Processing Record 7 of Set 7 | provideniya
# Processing Record 8 of Set 7 | sirjan
# Processing Record 9 of Set 7 | abu samrah
# Processing Record 10 of Set 7 | seredka
# Processing Record 11 of Set 7 | kuytun
# Processing Record 12 of Set 7 | itabira
# Processing Record 13 of Set 7 | tenenkou
# Processing Record 14 of Set 7 | leninskoye
# Processing Record 15 of Set 7 | airai
# Processing Record 16 of Set 7 | esperance
# Processing Record 17 of Set 7 | freeport
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 7 | haines junction
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | mitchell
# Processing Record 23 of Set 7 | parana
# Processing Record 24 of Set 7 | dzierzoniow
# Processing Record 25 of Set 7 | hammerfest
# Processing Record 26 of Set 7 | slave lake
# Processing Record 27 of Set 7 | tingo maria
# Processing Record 28 of Set 7 | todos santos
# Processing Record 29 of Set 7 | yaan
# Processing Record 30 of Set 7 | gus-zheleznyy
# Processing Record 31 of Set 7 | manyana
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | christchurch
# Processing Record 34 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 7 | masallatah
# Processing Record 36 of Set 7 | terracina
# Processing Record 37 of Set 7 | nuuk
# Processing Record 38 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | aguimes
# Processing Record 40 of Set 7 | monte patria
# Processing Record 41 of Set 7 | garissa
# Processing Record 42 of Set 7 | taoudenni
# Processing Record 43 of Set 7 | camacupa
# Processing Record 44 of Set 7 | roebourne
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | narsaq
# Processing Record 47 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | juruti
# Processing Record 49 of Set 7 | popondetta
# Processing Record 50 of Set 7 | fenoarivo atsinanana
# Processing Record 1 of Set 8 | presidencia roque saenz pena
# Processing Record 2 of Set 8 | gigmoto
# Processing Record 3 of Set 8 | bell ville
# Processing Record 4 of Set 8 | saint george
# Processing Record 5 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 8 | beloha
# Processing Record 7 of Set 8 | nikolskoye
# Processing Record 8 of Set 8 | vanimo
# Processing Record 9 of Set 8 | wolow
# Processing Record 10 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 8 | dubbo
# Processing Record 12 of Set 8 | bandarbeyla
# Processing Record 13 of Set 8 | utinga
# Processing Record 14 of Set 8 | karratha
# Processing Record 15 of Set 8 | hede
# Processing Record 16 of Set 8 | orem
# Processing Record 17 of Set 8 | pangody
# Processing Record 18 of Set 8 | caxias
# Processing Record 19 of Set 8 | baiyin
# Processing Record 20 of Set 8 | powell river
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | poum
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | khatanga
# Processing Record 25 of Set 8 | durusu
# Processing Record 26 of Set 8 | kenai
# Processing Record 27 of Set 8 | hualmay
# Processing Record 28 of Set 8 | verkhniy fiagdon
# Processing Record 29 of Set 8 | gemena
# Processing Record 30 of Set 8 | iquitos
# Processing Record 31 of Set 8 | suntar
# Processing Record 32 of Set 8 | worland
# Processing Record 33 of Set 8 | bolshaya sosnova
# Processing Record 34 of Set 8 | tual
# Processing Record 35 of Set 8 | te anau
# Processing Record 36 of Set 8 | finschhafen
# Processing Record 37 of Set 8 | marzuq
# Processing Record 38 of Set 8 | yanam
# Processing Record 39 of Set 8 | makakilo city
# Processing Record 40 of Set 8 | tawau
# Processing Record 41 of Set 8 | caramay
# Processing Record 42 of Set 8 | pujehun
# Processing Record 43 of Set 8 | bilibino
# Processing Record 44 of Set 8 | mariental
# Processing Record 45 of Set 8 | pringsewu
# Processing Record 46 of Set 8 | gamboula
# Processing Record 47 of Set 8 | tessalit
# Processing Record 48 of Set 8 | athabasca
# Processing Record 49 of Set 8 | nelson bay
# Processing Record 50 of Set 8 | sagar
# Processing Record 1 of Set 9 | noumea
# Processing Record 2 of Set 9 | sulzbach-rosenberg
# Processing Record 3 of Set 9 | tchollire
# Processing Record 4 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | mikhaylovka
# Processing Record 7 of Set 9 | lompoc
# Processing Record 8 of Set 9 | castro verde
# Processing Record 9 of Set 9 | kushima
# Processing Record 10 of Set 9 | kadnikov
# Processing Record 11 of Set 9 | inuvik
# Processing Record 12 of Set 9 | ningan
# City not found. Skipping...
# Processing Record 13 of Set 9 | havre-saint-pierre
# Processing Record 14 of Set 9 | sokolka
# Processing Record 15 of Set 9 | almaznyy
# Processing Record 16 of Set 9 | ballina
# Processing Record 17 of Set 9 | ulaanbaatar
# Processing Record 18 of Set 9 | muli
# Processing Record 19 of Set 9 | port hedland
# Processing Record 20 of Set 9 | dali
# Processing Record 21 of Set 9 | llangefni
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | dodola
# Processing Record 24 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 9 | leningradskiy
# Processing Record 26 of Set 9 | seoul
# Processing Record 27 of Set 9 | dera bugti
# Processing Record 28 of Set 9 | greytown
# Processing Record 29 of Set 9 | siguiri
# Processing Record 30 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 9 | barra
# Processing Record 32 of Set 9 | lapua
# Processing Record 33 of Set 9 | banki
# Processing Record 34 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 9 | deputatskiy
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | joacaba
# Processing Record 38 of Set 9 | mitu
# Processing Record 39 of Set 9 | dicabisagan
# Processing Record 40 of Set 9 | minyar
# Processing Record 41 of Set 9 | ust-ilimsk
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | vicuna
# Processing Record 44 of Set 9 | san policarpo
# Processing Record 45 of Set 9 | srednekolymsk
# Processing Record 46 of Set 9 | kavaratti
# Processing Record 47 of Set 9 | yorosso
# Processing Record 48 of Set 9 | moundsville
# Processing Record 49 of Set 9 | balakhta
# Processing Record 50 of Set 9 | westport
# Processing Record 1 of Set 10 | sringeri
# Processing Record 2 of Set 10 | kamenskiy
# Processing Record 3 of Set 10 | pilar
# Processing Record 4 of Set 10 | plettenberg bay
# Processing Record 5 of Set 10 | gwadar
# Processing Record 6 of Set 10 | nador
# Processing Record 7 of Set 10 | viedma
# Processing Record 8 of Set 10 | geraldton
# Processing Record 9 of Set 10 | zhezkazgan
# Processing Record 10 of Set 10 | lisakovsk
# Processing Record 11 of Set 10 | yhu
# Processing Record 12 of Set 10 | chipata
# Processing Record 13 of Set 10 | awbari
# Processing Record 14 of Set 10 | kourou
# Processing Record 15 of Set 10 | tyukhtet
# Processing Record 16 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 10 | kitimat
# Processing Record 18 of Set 10 | aykhal
# Processing Record 19 of Set 10 | dalby
# Processing Record 20 of Set 10 | vanavara
# Processing Record 21 of Set 10 | sawakin
# Processing Record 22 of Set 10 | chapais
# Processing Record 23 of Set 10 | san rafael
# Processing Record 24 of Set 10 | vostok
# Processing Record 25 of Set 10 | avallon
# Processing Record 26 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 10 | barroualie
# City not found. Skipping...
# Processing Record 28 of Set 10 | berdigestyakh
# Processing Record 29 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | alta floresta
# Processing Record 32 of Set 10 | oistins
# Processing Record 33 of Set 10 | rassvet
# Processing Record 34 of Set 10 | prainha
# Processing Record 35 of Set 10 | bury saint edmunds
# City not found. Skipping...
# Processing Record 36 of Set 10 | mericleri
# City not found. Skipping...
# Processing Record 37 of Set 10 | okha
# Processing Record 38 of Set 10 | chikwawa
# Processing Record 39 of Set 10 | sinnamary
# Processing Record 40 of Set 10 | abomsa
# Processing Record 41 of Set 10 | lyubech
# Processing Record 42 of Set 10 | carsamba
# Processing Record 43 of Set 10 | colesberg
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | dunedin
# Processing Record 46 of Set 10 | batagay-alyta
# Processing Record 47 of Set 10 | baykit
# Processing Record 48 of Set 10 | zhicheng
# Processing Record 49 of Set 10 | toulepleu
# City not found. Skipping...
# Processing Record 50 of Set 10 | tekkali
# Processing Record 1 of Set 11 | velizy-villacoublay
# Processing Record 2 of Set 11 | evensk
# Processing Record 3 of Set 11 | paamiut
# Processing Record 4 of Set 11 | lazarev
# Processing Record 5 of Set 11 | zhanaozen
# Processing Record 6 of Set 11 | jaru
# Processing Record 7 of Set 11 | fort myers beach
# Processing Record 8 of Set 11 | newport
# Processing Record 9 of Set 11 | sieradz
# Processing Record 10 of Set 11 | na wa
# Processing Record 11 of Set 11 | ilinskiy
# Processing Record 12 of Set 11 | inirida
# Processing Record 13 of Set 11 | jiuquan
# Processing Record 14 of Set 11 | lagoa
# Processing Record 15 of Set 11 | tanabe
# Processing Record 16 of Set 11 | moree
# Processing Record 17 of Set 11 | raudeberg
# Processing Record 18 of Set 11 | luganville
# Processing Record 19 of Set 11 | souillac
# Processing Record 20 of Set 11 | chuy
# Processing Record 21 of Set 11 | yar-sale
# Processing Record 22 of Set 11 | riviere-au-renard
# Processing Record 23 of Set 11 | sao filipe
# Processing Record 24 of Set 11 | kentau
# Processing Record 25 of Set 11 | najran
# Processing Record 26 of Set 11 | tamandare
# Processing Record 27 of Set 11 | natal
# Processing Record 28 of Set 11 | biu
# Processing Record 29 of Set 11 | bathsheba
# Processing Record 30 of Set 11 | chernyshevskiy
# Processing Record 31 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 32 of Set 11 | turukhansk
# Processing Record 33 of Set 11 | umea
# Processing Record 34 of Set 11 | henties bay
# Processing Record 35 of Set 11 | katherine
# Processing Record 36 of Set 11 | beringovskiy
# Processing Record 37 of Set 11 | rio grande
# Processing Record 38 of Set 11 | vegachi
# Processing Record 39 of Set 11 | bodrum
# Processing Record 40 of Set 11 | cabedelo
# Processing Record 41 of Set 11 | tambovka
# Processing Record 42 of Set 11 | itoman
# Processing Record 43 of Set 11 | tornio
# Processing Record 44 of Set 11 | severnyy
# Processing Record 45 of Set 11 | saint-francois
# Processing Record 46 of Set 11 | ca mau
# Processing Record 47 of Set 11 | sao miguel do araguaia
# Processing Record 48 of Set 11 | kiunga
# Processing Record 49 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | sayyan
# Processing Record 1 of Set 12 | mangan
# Processing Record 2 of Set 12 | gunjur
# Processing Record 3 of Set 12 | husavik
# Processing Record 4 of Set 12 | finote selam
# Processing Record 5 of Set 12 | fomboni
# Processing Record 6 of Set 12 | beian
# Processing Record 7 of Set 12 | port shepstone
# Processing Record 8 of Set 12 | merauke
# Processing Record 9 of Set 12 | iracoubo
# Processing Record 10 of Set 12 | ulladulla
# Processing Record 11 of Set 12 | macamic
# Processing Record 12 of Set 12 | mosbach
# Processing Record 13 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 12 | miles city
# Processing Record 15 of Set 12 | chipinge
# Processing Record 16 of Set 12 | petropavlovskoye
# Processing Record 17 of Set 12 | xuanhua
# Processing Record 18 of Set 12 | yining
# Processing Record 19 of Set 12 | maniitsoq
# Processing Record 20 of Set 12 | lake havasu city
# Processing Record 21 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 12 | limenaria
# Processing Record 23 of Set 12 | malazgirt
# Processing Record 24 of Set 12 | luncavita
# Processing Record 25 of Set 12 | karla
# Processing Record 26 of Set 12 | araouane
# Processing Record 27 of Set 12 | khagaria
# Processing Record 28 of Set 12 | dombarovskiy
# Processing Record 29 of Set 12 | mujiayingzi
# Processing Record 30 of Set 12 | kindu
# Processing Record 31 of Set 12 | linhares
# Processing Record 32 of Set 12 | liverpool
# Processing Record 33 of Set 12 | shahpur
# Processing Record 34 of Set 12 | hecun
# Processing Record 35 of Set 12 | jishou
# Processing Record 36 of Set 12 | dhidhdhoo
# Processing Record 37 of Set 12 | dilla
# Processing Record 38 of Set 12 | mount pleasant
# Processing Record 39 of Set 12 | hirado
# Processing Record 40 of Set 12 | salinopolis
# Processing Record 41 of Set 12 | huarmey
# Processing Record 42 of Set 12 | jacqueville
# Processing Record 43 of Set 12 | gazojak
# Processing Record 44 of Set 12 | talara
# Processing Record 45 of Set 12 | pangkalanbuun
# Processing Record 46 of Set 12 | itarema
# Processing Record 47 of Set 12 | ajdabiya
# Processing Record 48 of Set 12 | suez
# Processing Record 49 of Set 12 | darfo
# Processing Record 50 of Set 12 | ambon
# Processing Record 1 of Set 13 | tecoanapa
# Processing Record 2 of Set 13 | rehoboth
# Processing Record 3 of Set 13 | hofn
# Processing Record 4 of Set 13 | port hawkesbury
# Processing Record 5 of Set 13 | lekoni
# Processing Record 6 of Set 13 | amga
# Processing Record 7 of Set 13 | mindelo
# Processing Record 8 of Set 13 | ransang
# Processing Record 9 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 13 | mildura
# Processing Record 11 of Set 13 | tura
# Processing Record 12 of Set 13 | gazli
# Processing Record 13 of Set 13 | hirara
# Processing Record 14 of Set 13 | drayton valley
# Processing Record 15 of Set 13 | campos belos
# Processing Record 16 of Set 13 | manuk mangkaw
# Processing Record 17 of Set 13 | gimli
# Processing Record 18 of Set 13 | locri
# Processing Record 19 of Set 13 | fort nelson
# Processing Record 20 of Set 13 | north platte
# Processing Record 21 of Set 13 | artigas
# Processing Record 22 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 13 | havelock
# Processing Record 24 of Set 13 | corn island
# Processing Record 25 of Set 13 | coihaique
# Processing Record 26 of Set 13 | dong hoi
# Processing Record 27 of Set 13 | neryungri
# Processing Record 28 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 13 | sitrah
# Processing Record 30 of Set 13 | tanshui
# City not found. Skipping...
# Processing Record 31 of Set 13 | marienburg
# Processing Record 32 of Set 13 | orange cove
# Processing Record 33 of Set 13 | pustomyty
# Processing Record 34 of Set 13 | quelimane
# Processing Record 35 of Set 13 | porto san giorgio
# Processing Record 36 of Set 13 | orange
# Processing Record 37 of Set 13 | ugoofaaru
# Processing Record 38 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 13 | lake cowichan
# Processing Record 40 of Set 13 | omboue
# Processing Record 41 of Set 13 | hazaribag
# Processing Record 42 of Set 13 | trairi
# Processing Record 43 of Set 13 | auki
# Processing Record 44 of Set 13 | mount isa
# Processing Record 45 of Set 13 | wasilla
# Processing Record 46 of Set 13 | nhulunbuy
# Processing Record 47 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 13 | atar
# Processing Record 49 of Set 13 | port saint john
# Processing Record 50 of Set 13 | two hills
# Processing Record 1 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 14 | san cristobal
# Processing Record 3 of Set 14 | sault sainte marie
# Processing Record 4 of Set 14 | kermanshah
# Processing Record 5 of Set 14 | buchanan
# Processing Record 6 of Set 14 | nyurba
# Processing Record 7 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 14 | saveh
# Processing Record 9 of Set 14 | faya
# Processing Record 10 of Set 14 | porto novo
# Processing Record 11 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 14 | dumas
# Processing Record 13 of Set 14 | paslek
# Processing Record 14 of Set 14 | harbour breton
# Processing Record 15 of Set 14 | namatanai
# Processing Record 16 of Set 14 | sept-iles
# Processing Record 17 of Set 14 | clyde
# Processing Record 18 of Set 14 | cerro largo
# Processing Record 19 of Set 14 | north battleford
# Processing Record 20 of Set 14 | sabang
# Processing Record 21 of Set 14 | beyneu
# Processing Record 22 of Set 14 | veliki crljeni
# Processing Record 23 of Set 14 | chumphon
# Processing Record 24 of Set 14 | bay roberts
# Processing Record 25 of Set 14 | asau
# Processing Record 26 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 14 | lichuan
# Processing Record 28 of Set 14 | iquique
# Processing Record 29 of Set 14 | sadasivpet
# Processing Record 30 of Set 14 | bellevue
# Processing Record 31 of Set 14 | invermere
# Processing Record 32 of Set 14 | uchiza
# Processing Record 33 of Set 14 | ambilobe
# Processing Record 34 of Set 14 | gat
# Processing Record 35 of Set 14 | gushikawa
# Processing Record 36 of Set 14 | bereda
# Processing Record 37 of Set 14 | tombouctou
# Processing Record 38 of Set 14 | derzhavinsk
# Processing Record 39 of Set 14 | demirci
# Processing Record 40 of Set 14 | yulara
# Processing Record 41 of Set 14 | pirna
# Processing Record 42 of Set 14 | moerai
# Processing Record 43 of Set 14 | altay
# Processing Record 44 of Set 14 | avera
# Processing Record 45 of Set 14 | yate
# Processing Record 46 of Set 14 | henderson
# Processing Record 47 of Set 14 | sergeyevka
# Processing Record 48 of Set 14 | independencia
# Processing Record 49 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 14 | santa rosa
# Processing Record 1 of Set 15 | aracuai
# Processing Record 2 of Set 15 | loreto
# Processing Record 3 of Set 15 | gravdal
# Processing Record 4 of Set 15 | shenjiamen
# Processing Record 5 of Set 15 | krasnyy chikoy
# Processing Record 6 of Set 15 | bucharest
# Processing Record 7 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 15 | divnomorskoye
# Processing Record 9 of Set 15 | barra do garcas
# Processing Record 10 of Set 15 | garowe
# Processing Record 11 of Set 15 | nchelenge
# Processing Record 12 of Set 15 | dwarka
# Processing Record 13 of Set 15 | yamada
# Processing Record 14 of Set 15 | aleksandrov gay
# Processing Record 15 of Set 15 | shimoda
# Processing Record 16 of Set 15 | hit
# Processing Record 17 of Set 15 | port-cartier
# Processing Record 18 of Set 15 | port lincoln
# Processing Record 19 of Set 15 | windhoek
# Processing Record 20 of Set 15 | mareeba
# Processing Record 21 of Set 15 | pali
# Processing Record 22 of Set 15 | kirillov
# Processing Record 23 of Set 15 | hearst
# Processing Record 24 of Set 15 | samarai
# Processing Record 25 of Set 15 | monrovia
# Processing Record 26 of Set 15 | balaipungut
# Processing Record 27 of Set 15 | brownsville
# Processing Record 28 of Set 15 | igarka
# Processing Record 29 of Set 15 | mahenge
# Processing Record 30 of Set 15 | ialibu
# Processing Record 31 of Set 15 | baie-comeau
# Processing Record 32 of Set 15 | kalnibolotskaya
# Processing Record 33 of Set 15 | san isidro
# Processing Record 34 of Set 15 | teguldet
# Processing Record 35 of Set 15 | carbonear
# Processing Record 36 of Set 15 | oskarshamn
# Processing Record 37 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 15 | miandrivazo
# Processing Record 39 of Set 15 | bairiki
# Processing Record 40 of Set 15 | kedrovyy
# Processing Record 41 of Set 15 | bandar-e lengeh
# Processing Record 42 of Set 15 | joensuu
# Processing Record 43 of Set 15 | ampanihy
# Processing Record 44 of Set 15 | kuching
# Processing Record 45 of Set 15 | iranshahr
# Processing Record 46 of Set 15 | filingue
# Processing Record 47 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 15 | golden
# Processing Record 49 of Set 15 | conakry
# Processing Record 50 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 16 | baruun-urt
# Processing Record 2 of Set 16 | bandar
# Processing Record 3 of Set 16 | olinda
# Processing Record 4 of Set 16 | lexington park
# Processing Record 5 of Set 16 | sangar
# Processing Record 6 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 16 | maceio
# Processing Record 8 of Set 16 | halifax
# Processing Record 9 of Set 16 | peschanokopskoye
# Processing Record 10 of Set 16 | inhapim
# Processing Record 11 of Set 16 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 16 | weligama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Mahebourg -20.4081   57.7000     68.25        82          20        5.75
# 1     Qaanaaq  77.4840  -69.3632    -17.19        75           2        7.70
# 2      Miyako  39.6367  141.9525     43.00        55           0        3.11
# 3  Santa Cruz -17.8000  -63.1667     91.45        38           5       10.36
# 4   Busselton -33.6500  115.3333     52.95        76         100       17.74
# 5     Fortuna  40.5982 -124.1573     54.91        84           0       11.50
# 6  Bredasdorp -34.5322   20.0403     59.59        63         100        1.28
# 7  Solnechnyy  50.7214  136.6319     19.83        83         100        2.98
# 8      Hobart -42.8794  147.3294     61.27        67          20        3.44
# 9      Albany  42.6001  -73.9662     35.58        62          35        1.99
#
#   Country Current Description
# 0      MU          few clouds
# 1      GL           clear sky
# 2      JP           clear sky
# 3      BO           clear sky
# 4      AU     overcast clouds
# 5      US           clear sky
# 6      ZA     overcast clouds
# 7      RU     overcast clouds
# 8      AU          few clouds
# 9      US    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_names=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[column_names]

# Display sample data
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Mahebourg      MU -20.4081   57.7000     68.25        82
# 1             Qaanaaq      GL  77.4840  -69.3632    -17.19        75
# 2              Miyako      JP  39.6367  141.9525     43.00        55
# 3          Santa Cruz      BO -17.8000  -63.1667     91.45        38
# 4           Busselton      AU -33.6500  115.3333     52.95        76
# ..                ...     ...      ...       ...       ...       ...
# 690            Maceio      BR  -9.6658  -35.7353     74.64        94
# 691           Halifax      CA  44.6453  -63.5724     38.68        65
# 692  Peschanokopskoye      RU  46.1961   41.0775     53.13        53
# 693           Inhapim      BR -19.5492  -42.1200     66.97        86
# 694          Weligama      LK   5.9667   80.4167     74.28        90
#
#      Cloudiness  Wind Speed Current Description
# 0            20        5.75          few clouds
# 1             2        7.70           clear sky
# 2             0        3.11           clear sky
# 3             5       10.36           clear sky
# 4           100       17.74     overcast clouds
# ..          ...         ...                 ...
# 690          20        6.91          few clouds
# 691          81       11.99       broken clouds
# 692          87       15.57     overcast clouds
# 693          57        6.08       broken clouds
# 694          77        4.74       broken clouds
#
# [695 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
